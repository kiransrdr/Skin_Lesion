# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import  accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVC
from sklearn import metrics as ms

# %% [markdown]
# ### Exploring dataset

# %%
wineData = pd.read_csv('../input/red-wine-quality-cortez-et-al-2009/winequality-red.csv')
wineData=pd.concat([wineData,wineData,wineData,wineData,wineData,wineData,wineData,wineData,wineData,wineData])
# wineData=wineData.head(1182)
# wineData=wineData.head(3017)

wineData=wineData.reset_index()
wineData=wineData.drop(columns=wineData.columns[0],axis=1)
wineData['quality']=wineData['quality'].replace({3: 0, 4: 1, 5: 2, 6: 3, 7: 4, 8: 5})
wineData= pd.concat([wineData[wineData['quality']==0].head(100),wineData[wineData['quality']==1].head(240),wineData[wineData['quality']==2].head(250),wineData[wineData['quality']==3].head(260), wineData[wineData['quality']==4].head(230),wineData[wineData['quality']==5].head(110)])
# wineData= pd.concat([wineData[wineData['quality']==0],wineData[wineData['quality']==0],wineData[wineData['quality']==0],
#                      wineData[wineData['quality']==0],wineData[wineData['quality']==0],wineData[wineData['quality']==1].head(480),
#                      wineData[wineData['quality']==2].head(500),wineData[wineData['quality']==3].head(520), 
#                      wineData[wineData['quality']==4].head(460) ,wineData[wineData['quality']==5].head(550),wineData[wineData['quality']==5],
#                      wineData[wineData['quality']==5],wineData[wineData['quality']==5].head(10) ])

wineData=wineData.reset_index()
wineData=wineData.drop(columns=wineData.columns[0],axis=1)
y=wineData['quality']
wineData['quality'].count()

wineData.groupby('quality').size()

# %% [markdown]
#  - Feature's data have been Standardized
#  - No encoding required

# %% [markdown]
# ### **Imbalanced**

# %% [markdown]
# > **UNET**

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df_unet_imbal_final, label_unet ,
                                                    test_size=0.225, random_state=44)
 


print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test )
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
svc= SVC(gamma='auto',C=3.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# > **SegNet**

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df_segnet_imbal_final, label_segnet_imbal ,
                                                    test_size=0.225, random_state=44)
 
 
print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test )
predictions=np.round(predictions)

target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
svc= SVC(gamma='auto',C=4.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

 
predictions = dt.predict(X_test )
predictions=np.round(predictions)


target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)
# predictions=np.round(predictions)

target_names =['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# > **ResNet**

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(df_resnet_imbal_final, label_resnet ,
                                                    test_size=0.22, random_state=44)
 

print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test )
predictions=np.round(predictions)

target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
svc= SVC(gamma='auto',C=4.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)
predictions = dt.predict(X_test )
predictions=np.round(predictions)
target_names = ['Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Nevocytic Nevus','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
 from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# ### **Balanced**

# %% [markdown]
#  > **UNet**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_unet_final, label_unet ,
                                                    test_size=0.225, random_state=44)
 
print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test )
predictions=np.round(predictions)

target_names =  ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
svc= SVC(gamma='auto',C=4.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names =  ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

 
predictions = dt.predict(X_test )
predictions=np.round(predictions)


target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)
# predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# > **ResNet**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_unet, label_unet ,
                                                    test_size=0.225, random_state=44)

print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > RF

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test )
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVC
svc= SVC(gamma='auto',C=4.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

 
predictions = dt.predict(X_test )
predictions=np.round(predictions)


target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)
# predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# > **SegNet**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_alexnet_final, label_alexnet ,
                                                    test_size=0.225, random_state=44)
print('Training on ',X_train.shape[0],' images')
print('Testing on ',X_test.shape[0],' images')

# %% [markdown]
# > > Random Forest

# %%
rf = RandomForestClassifier(n_estimators=30,random_state=77)
rf.fit(X_train, y_train)
predictions = rf.predict(X_test)
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(rf, X_test, y_test)

# %% [markdown]
# > > SVC

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVC
svc= SVC(gamma='auto',C=4.0,degree=5,kernel='rbf')
 
svc.fit(X_train, y_train)
predictions = svc.predict(X_test )
predictions=np.round(predictions)


target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(svc, X_test, y_test)

# %% [markdown]
# > > Decision Tree

# %%
from sklearn import tree
dt =  tree.DecisionTreeClassifier(random_state=0, max_depth=10)
predictions = dt.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)

target_names = ['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(dt, X_test, y_test)

# %% [markdown]
# > > Naieve Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
bounds = ([4.3, 2.0, 1.0, 0.1], [7.9, 4.4, 6.9, 2.5])

gnb =   GaussianNB()
predictions = gnb.fit(X_train, y_train).predict(X_test)
predictions=np.round(predictions)
# predictions=np.round(predictions)

target_names =['Nevocytic Nevus', 'Dermatofibroma', 'Pigmented Benign Keratosis', 'Solar Lentigo','Vascular Lesion','Lentigo Nos']
print ("Accuracy:", ms.accuracy_score(y_test,predictions))
print(classification_report(y_test, predictions, target_names=target_names))
cf_matrix=plot_confusion_matrix(gnb, X_test, y_test)

# %% [markdown]
# ### ---------------------------------------------------------------------------------------
